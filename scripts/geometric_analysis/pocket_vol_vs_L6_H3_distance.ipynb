# %%
import pandas as pd
import seaborn as sns
import numpy as np
import re
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# HP1
#unb
HP1_UNB_VOL_S1=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM1-HP1.csv',
                      index_col=0)
HP1_UNB_VOL_S2=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM2-HP1.csv',
                      index_col=0)
HP1_UNB_VOL_S3=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM3-HP1.csv',
                      index_col=0)

#bnd
HP1_BND_VOL_S1=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM1-HP1.csv',
                      index_col=0)
HP1_BND_VOL_S2=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM2-HP1.csv',
                      index_col=0)
HP1_BND_VOL_S3=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM3-HP1.csv',
                      index_col=0)

# pre 

HP1_PRO_VOL_S1=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM1-HP1.csv',
                      index_col=0)
HP1_PRO_VOL_S2=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM2-HP1.csv',
                      index_col=0)
HP1_PRO_VOL_S3=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM3-HP1.csv',
                      index_col=0)

#-----------------
#FINAL LIST
HP1_UNB_VOL_ALL=HP1_UNB_VOL_S1[' VOLUME (A^3) '].to_list()+HP1_UNB_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP1_UNB_VOL_S3[' VOLUME (A^3) '].to_list()

HP1_BND_VOL_ALL=HP1_BND_VOL_S1[' VOLUME (A^3) '].to_list()+HP1_BND_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP1_BND_VOL_S3[' VOLUME (A^3) '].to_list()

HP1_PRE_VOL_ALL=HP1_PRO_VOL_S1[' VOLUME (A^3) '].to_list()+HP1_PRO_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP1_PRO_VOL_S3[' VOLUME (A^3) '].to_list()

# %%
#HP2
#unb
HP2_UNB_VOL_S1=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM1-HP2.csv',
                      index_col=0)
HP2_UNB_VOL_S2=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM2-HP2.csv',
                      index_col=0)
HP2_UNB_VOL_S3=pd.read_csv('../../data/pocket_volume/UNB/LC3B-ER-PV-SIM3-HP2.csv',
                      index_col=0)

#bnd
HP2_BND_VOL_S1=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM1-HP2.csv',
                      index_col=0)
HP2_BND_VOL_S2=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM2-HP2.csv',
                      index_col=0)
HP2_BND_VOL_S3=pd.read_csv('../../data/pocket_volume/BND/LC3B-p62-ER-PV-SIM3-HP2.csv',
                      index_col=0)

# pre 

HP2_PRO_VOL_S1=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM1-HP2.csv',
                      index_col=0)
HP2_PRO_VOL_S2=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM2-HP2.csv',
                      index_col=0)
HP2_PRO_VOL_S3=pd.read_csv('../../data/pocket_volume/PRE/proLC3B-OPLS-PV-SIM3-HP2.csv',
                      index_col=0)

#-----------------
#FINAL LIST
HP2_UNB_VOL_ALL=HP2_UNB_VOL_S1[' VOLUME (A^3) '].to_list()+HP2_UNB_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP2_UNB_VOL_S3[' VOLUME (A^3) '].to_list()

HP2_BND_VOL_ALL=HP2_BND_VOL_S1[' VOLUME (A^3) '].to_list()+HP2_BND_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP2_BND_VOL_S3[' VOLUME (A^3) '].to_list()

HP2_PRE_VOL_ALL=HP2_PRO_VOL_S1[' VOLUME (A^3) '].to_list()+HP2_PRO_VOL_S2[' VOLUME (A^3) '].to_list()+\
HP2_PRO_VOL_S3[' VOLUME (A^3) '].to_list()

# %%
PRE_PV_df=pd.DataFrame()
PRE_PV_df['HP1']=HP1_PRE_VOL_ALL
PRE_PV_df['HP2']=HP2_PRE_VOL_ALL

unb_PV_df=pd.DataFrame()
unb_PV_df['HP1']=HP1_UNB_VOL_ALL
unb_PV_df['HP2']=HP2_UNB_VOL_ALL

bnd_PV_df=pd.DataFrame()
bnd_PV_df['HP1']=HP1_BND_VOL_ALL
bnd_PV_df['HP2']=HP2_BND_VOL_ALL

PRE_PV_df['net vol']=[i+j for i,j in zip(PRE_PV_df['HP1'],
                                        PRE_PV_df['HP2'])]
unb_PV_df['net vol']=[i+j for i,j in zip(unb_PV_df['HP1'],
                                        unb_PV_df['HP2'])]
bnd_PV_df['net vol']=[i+j for i,j in zip(bnd_PV_df['HP1'],
                                        bnd_PV_df['HP2'])]

# %%
import MDAnalysis
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/MDAnalysis/topology/TPRParser.py:161: DeprecationWarning: 'xdrlib' is deprecated and slated for removal in Python 3.13
#   import xdrlib

# %%
prefix_path='../../../LC3_MAIN_TRAJECTORIES/PROTEIN_ONLY_FITTED'

#PRE
u_unbound_pre_S1=MDAnalysis.Universe('%s/preLC3B_OPLS/preLC3B_OPLS_SIM1_dt1000.pdb'%prefix_path)
u_unbound_pre_S2=MDAnalysis.Universe('%s/preLC3B_OPLS/preLC3B_OPLS_SIM2_dt1000.pdb'%prefix_path)
u_unbound_pre_S3=MDAnalysis.Universe('%s/preLC3B_OPLS/preLC3B_OPLS_SIM3_dt1000.pdb'%prefix_path)


#UNB
u_unbound_ER_S1 = MDAnalysis.Universe("%s/LC3B_II_ER_protein/LC3B_II_ER_protein_SIM1_dt1000.pdb"%prefix_path)
u_unbound_ER_S2 =MDAnalysis.Universe("%s/LC3B_II_ER_protein/LC3B_II_ER_protein_SIM2_dt1000.pdb"%prefix_path)
u_unbound_ER_S3=MDAnalysis.Universe("%s/LC3B_II_ER_protein/LC3B_II_ER_protein_SIM3_dt1000.pdb"%prefix_path)

#BND
u_bound_ER_S1 = MDAnalysis.Universe("%s/LC3B_P62_INCLUDED/LC3B_P62_INCLUDED_SIM1_dt1000.pdb"%prefix_path)
u_bound_ER_S2 = MDAnalysis.Universe("%s/LC3B_P62_INCLUDED/LC3B_P62_INCLUDED_SIM2_dt1000.pdb"%prefix_path)
u_bound_ER_S3 = MDAnalysis.Universe("%s/LC3B_P62_INCLUDED/LC3B_P62_INCLUDED_SIM3_dt1000.pdb"%prefix_path)

# %%
#min distance

def min_dist(Traj,pairs):
    distt_ls=[]
    total_frames=len(Traj.trajectory)

    for t in Traj.trajectory:
        #selecting all the heavy atoms 
        sel1=Traj.select_atoms('resid %d and not type H'%pairs[0])
        sel2=Traj.select_atoms('resid %d and not type H'%pairs[1])
        dist_ls=[]
        for i in sel1.atoms:
            for j in sel2.atoms:

                pos_1=np.array(i.position)  
                pos_2=np.array(j.position)

                dist=np.linalg.norm(pos_1 - pos_2)
                dist_ls.append(dist)
        distt_ls.append(min(dist_ls))
    return(distt_ls)

# %%
req_pairs=[(64,89),(60,91)] # between H3-L6 residue pairs


#dist b/w 64 and 89
lc3b_unb_mindist_1=min_dist(u_unbound_ER_S1,req_pairs[0])+min_dist(u_unbound_ER_S1,req_pairs[0])+min_dist(u_unbound_ER_S3,req_pairs[0])
lc3b_bnd_mindist_1=min_dist(u_bound_ER_S1,req_pairs[0])+min_dist(u_bound_ER_S2,req_pairs[0])+min_dist(u_bound_ER_S3,req_pairs[0])
pre_mindist_1=min_dist(u_unbound_pre_S1,req_pairs[0])+min_dist(u_unbound_pre_S2,req_pairs[0])+\
min_dist(u_unbound_pre_S3,req_pairs[0])


#dist b/w 60 and 91
lc3b_unb_mindist_2=min_dist(u_unbound_ER_S1,req_pairs[1])+min_dist(u_unbound_ER_S2,req_pairs[1])+min_dist(u_unbound_ER_S3,req_pairs[1])
lc3b_bnd_mindist_2=min_dist(u_bound_ER_S1,req_pairs[1])+min_dist(u_bound_ER_S2,req_pairs[1])+min_dist(u_bound_ER_S3,req_pairs[1])
pre_mindist_2=min_dist(u_unbound_pre_S1,req_pairs[1])+min_dist(u_unbound_pre_S2,req_pairs[1])+\
min_dist(u_unbound_pre_S3,req_pairs[1])

# %%
# calculate mean of two distances

mean_lc3b_unb_mindist=[(i+j)/2 for i,j in zip(lc3b_unb_mindist_1,lc3b_unb_mindist_2)]
mean_lc3b_bnd_mindist=[(i+j)/2 for i,j in zip(lc3b_bnd_mindist_1,lc3b_bnd_mindist_2)]
mean_lc3b_pre_mindist=[(i+j)/2 for i,j in zip(pre_mindist_1,pre_mindist_2)]

# %%
PRE_PV_df['L6-H3 MEAN DIST']=mean_lc3b_pre_mindist
unb_PV_df['L6-H3 MEAN DIST']=mean_lc3b_unb_mindist
bnd_PV_df['L6-H3 MEAN DIST']=mean_lc3b_bnd_mindist

# %%
def manhattan_dist_1d(p1,p2):
    manhattan_dist=abs(p1-p2)
    return(manhattan_dist)

def chebyshev_dist(p1,p2):
    return(max(np.abs(p1[0]-p2[0]),np.abs(p1[1]-p2[1])))

def neigh_ret(k_val, df_n):
    k3_all=k_val


    xy=[]
    for i,j in zip(df_n['net vol'],
                df_n['L6-H3 MEAN DIST']):
        xy.append([i/max(df_n['net vol']),j/max(df_n['L6-H3 MEAN DIST'])])

    neigh=[]
    for i in xy:
        counter=0
        ref_point=i
        radius=[]
        for j in xy:
            if j!=ref_point:
                dist_measure=chebyshev_dist(ref_point,j)
                if dist_measure<k3_all:
                    counter=counter+1

        neigh.append(counter) 
    
    return neigh

# %%
PRE_PV_df['neigh']=neigh_ret(0.06, PRE_PV_df)
PRE_PV_df=PRE_PV_df.sort_values(by='neigh',
                                  ascending=False)
PRE_PV_df['norm_neigh']=[i/max(PRE_PV_df['neigh']) for i in PRE_PV_df['neigh']]

unb_PV_df['neigh']=neigh_ret(0.05, unb_PV_df)
unb_PV_df=unb_PV_df.sort_values(by='neigh',
                                  ascending=False)
unb_PV_df['norm_neigh']=[i/max(unb_PV_df['neigh']) for i in unb_PV_df['neigh']]


bnd_PV_df['neigh']=neigh_ret(0.05, bnd_PV_df)
bnd_PV_df=bnd_PV_df.sort_values(by='neigh',
                                  ascending=False)
bnd_PV_df['norm_neigh']=[i/max(bnd_PV_df['neigh']) for i in bnd_PV_df['neigh']]

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(PRE_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(PRE_PV_df['net vol'],
            PRE_PV_df['L6-H3 MEAN DIST'],
            c=PRE_PV_df['norm_neigh'],
           cmap='tab20b',s=50)

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)

plt.savefig('../../plots/geometric_analysis/triad_distance_vs_net_pock_vol_pre.png', 
                   dpi=650, bbox_inches='tight',
           transparent=True)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(unb_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(unb_PV_df['net vol'],
            unb_PV_df['L6-H3 MEAN DIST'],
            c=unb_PV_df['norm_neigh'],
           cmap='tab20b',s=50)

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)


plt.savefig('../../plots/geometric_analysis/triad_distance_vs_net_pock_vol_unb.png', 
                   dpi=650, bbox_inches='tight',
           transparent=True)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(bnd_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(bnd_PV_df['net vol'],
            bnd_PV_df['L6-H3 MEAN DIST'],
            c=bnd_PV_df['norm_neigh'],
           cmap='tab20b',s=50)

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)


plt.savefig('../../plots/geometric_analysis/triad_distance_vs_net_pock_vol_bnd.png', 
                   dpi=650, bbox_inches='tight',
           transparent=True)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
PRE_PV_df[(PRE_PV_df["norm_neigh"]>=0.9)&(PRE_PV_df["L6-H3 MEAN DIST"]>=6)]
# Out:
#          HP1     HP2  net vol  L6-H3 MEAN DIST  neigh  norm_neigh
# 1716   6.750  53.000   59.750         7.088364    370    0.943878
# 1788   7.750  55.750   63.500         6.900528    370    0.943878
# 1594   2.750  59.125   61.875         7.071445    369    0.941327
# 825    9.750  52.125   61.875         7.058286    369    0.941327
# 175    1.125  60.875   62.000         7.040468    369    0.941327
# ...      ...     ...      ...              ...    ...         ...
# 481   17.750  48.250   66.000         6.795412    353    0.900510
# 761    2.500  63.625   66.125         7.001886    353    0.900510
# 1264   3.250  62.625   65.875         7.104107    353    0.900510
# 313    2.750  64.625   67.375         6.795755    353    0.900510
# 1448   5.750  52.500   58.250         7.076055    353    0.900510
#
# [62 rows x 6 columns]

# %%
PRE_PV_df
# Out:
#          HP1      HP2  net vol  L6-H3 MEAN DIST  neigh  norm_neigh
# 2600   2.750   75.750   78.500         3.816671    392    1.000000
# 2519   6.875   72.625   79.500         3.784958    391    0.997449
# 2487   3.750   76.000   79.750         3.696544    391    0.997449
# 2234   7.000   71.750   78.750         3.870228    390    0.994898
# 2390   5.625   73.500   79.125         3.796261    390    0.994898
# ...      ...      ...      ...              ...    ...         ...
# 528   39.000   80.375  119.375         8.854317      1    0.002551
# 1079  47.750  132.500  180.250         4.673159      0    0.000000
# 628    7.125   83.625   90.750         9.230213      0    0.000000
# 1115  39.250  129.625  168.875         3.962768      0    0.000000
# 992   81.125   97.000  178.125         7.004728      0    0.000000
#
# [3003 rows x 6 columns]

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(PRE_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(PRE_PV_df['net vol'],
            PRE_PV_df['L6-H3 MEAN DIST'],
            c=PRE_PV_df['neigh'],
           cmap='tab20b',s=50)

ax.scatter(63.500, 6.900528,
          marker="*", color='white')

ax.scatter(78.500, 3.816671,
          marker="*", color='white')

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 0, 'Net HP Vol $(\\AA^3)$')

# %%
unb_PV_df
# Out:
#          HP1      HP2  net vol  L6-H3 MEAN DIST  neigh  norm_neigh
# 629   52.375   72.500  124.875         3.735888    503    1.000000
# 2155  25.625  103.625  129.250         3.742278    502    0.998012
# 614   50.125   78.750  128.875         3.691949    502    0.998012
# 1700  15.250  113.875  129.125         3.717576    502    0.998012
# 2198  37.000   91.750  128.750         3.694772    502    0.998012
# ...      ...      ...      ...              ...    ...         ...
# 1281  68.500  147.250  215.750         5.412849      1    0.001988
# 2802  19.375   45.500   64.875         6.008229      1    0.001988
# 1484  27.000  187.875  214.875         5.446910      1    0.001988
# 1418  29.875  205.750  235.625         5.391373      1    0.001988
# 1405  20.250   63.375   83.625         6.624179      0    0.000000
#
# [3003 rows x 6 columns]

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(unb_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(unb_PV_df['net vol'],
            unb_PV_df['L6-H3 MEAN DIST'],
            c=unb_PV_df['norm_neigh'],
           cmap='tab20b',s=50)

ax.scatter(124.875, 3.735888,
          marker="*", color='white')

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)



ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)


# plt.savefig('../../plots/geometric_analysis/triad_distance_vs_net_pock_vol_unb.png', 
#                    dpi=650, bbox_inches='tight',
#            transparent=True)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 0, 'Net HP Vol $(\\AA^3)$')

# %%
bnd_PV_df
# Out:
#          HP1      HP2  net vol  L6-H3 MEAN DIST  neigh  norm_neigh
# 1057  80.625   64.625  145.250         3.731045    660    1.000000
# 168   59.500   87.000  146.500         3.736331    660    1.000000
# 313   69.500   77.000  146.500         3.802028    658    0.996970
# 2117  50.375   95.625  146.000         3.746271    657    0.995455
# 879   59.375   84.000  143.375         3.765657    657    0.995455
# ...      ...      ...      ...              ...    ...         ...
# 2962  64.375  117.250  181.625         8.363501      1    0.001515
# 2889  81.500   94.750  176.250         8.322674      1    0.001515
# 2783  73.750  122.250  196.000         8.241184      1    0.001515
# 2888  95.625  122.750  218.375         8.294216      0    0.000000
# 2915  66.125  200.125  266.250         6.332816      0    0.000000
#
# [3003 rows x 6 columns]

# %%
bnd_PV_df[(bnd_PV_df["norm_neigh"]>=0.9)&(bnd_PV_df["net vol"]>=170)]
# Out:
#           HP1      HP2  net vol  L6-H3 MEAN DIST  neigh  norm_neigh
# 1334  116.375   68.375  184.750         3.758859    643    0.974242
# 2495   59.625  124.500  184.125         3.805427    643    0.974242
# 2212   41.375  142.500  183.875         3.827576    641    0.971212
# 1156  108.625   74.375  183.000         3.739280    640    0.969697
# 2531   66.375  121.000  187.375         3.753226    640    0.969697
# ...       ...      ...      ...              ...    ...         ...
# 1413  127.000   73.375  200.375         3.658351    594    0.900000
# 1767  118.500   58.000  176.500         3.700055    594    0.900000
# 1935  113.625   59.250  172.875         3.789371    594    0.900000
# 1100   97.625   80.000  177.625         3.660871    594    0.900000
# 1470  121.125   57.750  178.875         3.605231    594    0.900000
#
# [328 rows x 6 columns]

# %%
font = {'family':'helvetica neue',
            'color':  'black',
            'weight': 'bold',
            'size': 12
            }
rs={'family':'helvetica neue',
    'size':14
   }


fig, ax = plt.subplots(figsize=(5, 5))

sns.kdeplot(bnd_PV_df,
             x='net vol',
             y='L6-H3 MEAN DIST',cmap='tab20b')
ax.scatter(bnd_PV_df['net vol'],
            bnd_PV_df['L6-H3 MEAN DIST'],
            c=bnd_PV_df['norm_neigh'],
           cmap='tab20b',s=50)

ax.set_ylim(2,10)
ax.set_xlim(0,300)

ax.set_xlabel('Net HP Vol')
ax.set_ylabel('Dist')

ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed',alpha=0.1)
ax.xaxis.grid(color='gray', linestyle='dashed',alpha=0.1)

ax.tick_params(labelsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.scatter(145.250, 3.731045,
          marker="*", color='white')

ax.scatter(184.750, 3.758859,
          marker="*", color='white')

ax.set_ylabel('Mean triad distance $(\AA)$', fontdict=font)
ax.set_xlabel('Net HP Vol $(\AA^3)$', fontdict=font)


# plt.savefig('../../plots/geometric_analysis/triad_distance_vs_net_pock_vol_bnd.png', 
#                    dpi=650, bbox_inches='tight',
#            transparent=True)
# Out:
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jesucastin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 0, 'Net HP Vol $(\\AA^3)$')
